# %%
import pandas as pd
import seaborn as sb
file = pd.read_csv('Desktop/chocolate.csv')
file.head()
# Out:
#     Company Specific_Bean_Origin_or_Bar_Name   REF  Review_Date Cocoa_Percent  \
# 0  A. Morin                      Agua Grande  1876         2016           63%
# 1  A. Morin                            Kpime  1676         2015           70%
# 2  A. Morin                           Atsane  1676         2015           70%
# 3  A. Morin                            Akata  1680         2015           70%
# 4  A. Morin                           Quilla  1704         2015           70%
#
#   Company_Location  Rating Bean_Type Broad_Bean_Origin
# 0           France    3.75                    Sao Tome
# 1           France    2.75                        Togo
# 2           France    3.00                        Togo
# 3           France    3.50                        Togo
# 4           France    3.50                        Peru

# %%
file.describe()
# Out:
#                REF  Review_Date       Rating
# count  1795.000000  1795.000000  1795.000000
# mean   1035.904735  2012.325348     3.185933
# std     552.886365     2.927210     0.478062
# min       5.000000  2006.000000     1.000000
# 25%     576.000000  2010.000000     2.875000
# 50%    1069.000000  2013.000000     3.250000
# 75%    1502.000000  2015.000000     3.500000
# max    1952.000000  2017.000000     5.000000

# %%
file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 9 columns):
# Company                             1795 non-null object
# Specific_Bean_Origin_or_Bar_Name    1795 non-null object
# REF                                 1795 non-null int64
# Review_Date                         1795 non-null int64
# Cocoa_Percent                       1795 non-null object
# Company_Location                    1795 non-null object
# Rating                              1795 non-null float64
# Bean_Type                           1794 non-null object
# Broad_Bean_Origin                   1794 non-null object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 126.3+ KB

# %%
#Từ hàm info(): Bean Type và Broad Bean Origin có một record bị NULL

# %%
file[file['Broad_Bean_Origin'].isna()]
# Out:
#             Company Specific_Bean_Origin_or_Bar_Name  REF  Review_Date  \
# 1072  Mast Brothers                       Madagascar  999         2012
#
#      Cocoa_Percent Company_Location  Rating   Bean_Type Broad_Bean_Origin
# 1072           72%           U.S.A.     2.5  Trinitario               NaN

# %%
file[file['Bean_Type'].isna()]
# Out:
#      Company         Specific_Bean_Origin_or_Bar_Name  REF  Review_Date  \
# 1544    Soma  Three Amigos(Chuao, Wild Bolivia, D.R.)  676         2011
#
#      Cocoa_Percent Company_Location  Rating Bean_Type   Broad_Bean_Origin
# 1544           70%           Canada     4.0       NaN  Ven, Bolivia, D.R.

# %%
# vì số lượng dòng có giá trị null rất ít nên sẽ xóa luôn
file = file[file['Broad_Bean_Origin'].isna()==False]
file = file[file['Bean_Type'].isna()==False]

# %%
review_Date = file['Review_Date'].value_counts()

# %%
review_Date.plot(kind='bar')

# %%
rating = file['Rating'].value_counts()
rating.plot(kind = 'bar')

# %%
file[file['Rating']<3]['Company_Location'].value_counts()
# Out:
# U.S.A.            204
# U.K.               38
# France             35
# Canada             20
# Ecuador            20
# Belgium            11
# Australia           8
# Italy               7
# Peru                7
# Germany             6
# Colombia            6
# Madagascar          6
# Venezuela           6
# New Zealand         5
# Switzerland         5
# Hungary             5
# Spain               5
# Austria             4
# Puerto Rico         4
# Ireland             3
# Scotland            3
# Japan               3
# Israel              3
# Lithuania           2
# Grenada             2
# South Africa        2
# Argentina           2
# Portugal            2
# Mexico              2
# Nicaragua           2
# Brazil              2
# Costa Rica          2
# Niacragua           1
# Czech Republic      1
# Sao Tome            1
# Denmark             1
# Honduras            1
# South Korea         1
# Ghana               1
# Poland              1
# Sweden              1
# ...

# %%
file[file['Company_Location']=='U.S.A.']
# Out:
#                              Company         Specific_Bean_Origin_or_Bar_Name  \
# 23                            Acalli                  Chulucanas, El Platanal
# 24                            Acalli                        Tumbes, Norandino
# 44             Altus aka Cao Artisan                                Momotombo
# 45             Altus aka Cao Artisan                                 Acopagro
# 46             Altus aka Cao Artisan                               CIAAB Coop
# 47             Altus aka Cao Artisan                             Villa Andina
# 48             Altus aka Cao Artisan                           Gruppo Salinas
# 49             Altus aka Cao Artisan                             Sur del Lago
# 50             Altus aka Cao Artisan                                 Conacado
# 51             Altus aka Cao Artisan                                  Bolivia
# 52             Altus aka Cao Artisan                                  Bolivia
# ...

# %%
#vẽ biểu đồ thể hiện tỉ lệ giữa số lượng công ty sản xuất tại một nước và số lượng có Rating thấp (<3)
# tạo bảng gồm 3 cột dữ liệu: Location , Company, LowRating
